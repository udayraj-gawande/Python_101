# %%
x = 3
y = 4
print(x + y)
# Out:
# 7

# %%
Uday = "Uday"
number = 42
pointer = 7.4

# %%
Udaymarks = [71,82,93,64,75,86,97,68,79,90]

# %%
Uday1 = {"name": "Uday","age": 25, "city": "New York"    }

# %%
print(Uday)
print(number)
print(pointer)
# Out:
# Uday
# 42
# 7.4

# %%
print(Udaymarks)
# Out:
# [71, 82, 93, 64, 75, 86, 97, 68, 79, 90]

# %%
print(Uday1)
# Out:
# {'name': 'Uday', 'age': 25, 'city': 'New York'}
